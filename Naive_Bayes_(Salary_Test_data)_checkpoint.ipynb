# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("SalaryData_Test(1).csv")
df
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
df.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
df.tail()
# Out:
#        age      workclass   education  educationno        maritalstatus  \
# 15055   33        Private   Bachelors           13        Never-married
# 15056   39        Private   Bachelors           13             Divorced
# 15057   38        Private   Bachelors           13   Married-civ-spouse
# 15058   44        Private   Bachelors           13             Divorced
# 15059   35   Self-emp-inc   Bachelors           13   Married-civ-spouse
#
#              occupation    relationship                 race      sex  \
# 15055    Prof-specialty       Own-child                White     Male
# 15056    Prof-specialty   Not-in-family                White   Female
# 15057    Prof-specialty         Husband                White     Male
# 15058      Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 15059   Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# ...

# %%
list(df)
# Out:
# ['age',
#  'workclass',
#  'education',
#  'educationno',
#  'maritalstatus',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capitalgain',
#  'capitalloss',
#  'hoursperweek',
#  'native',
#  'Salary']

# %%
df.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  15060.000000  15060.000000  15060.000000  15060.000000  15060.000000
# mean      38.768327     10.112749   1120.301594     89.041899     40.951594
# std       13.380676      2.558727   7703.181842    406.283245     12.062831
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       48.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   3770.000000     99.000000

# %%
df.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %% [markdown]
# # Finding the special charaters in the data frame

# %%
df.isin(["?"]).sum(axis=0)
print(df[0:5])
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
df.native.value_counts()
df.native.unique()
# Out:
# array([' United-States', ' Peru', ' Guatemala', ' Mexico',
#        ' Dominican-Republic', ' Ireland', ' Germany', ' Philippines',
#        ' Thailand', ' Haiti', ' El-Salvador', ' Puerto-Rico', ' Vietnam',
#        ' South', ' Columbia', ' Japan', ' India', ' Cambodia', ' Poland',
#        ' Laos', ' England', ' Cuba', ' Taiwan', ' Italy', ' Canada',
#        ' Portugal', ' China', ' Nicaragua', ' Honduras', ' Iran',
#        ' Scotland', ' Jamaica', ' Ecuador', ' Yugoslavia', ' Hungary',
#        ' Hong', ' Greece', ' Trinadad&Tobago',
#        ' Outlying-US(Guam-USVI-etc)', ' France'], dtype=object)

# %%
df.workclass.value_counts()
df.workclass.unique()
# Out:
# array([' Private', ' Local-gov', ' Self-emp-not-inc', ' Federal-gov',
#        ' State-gov', ' Self-emp-inc', ' Without-pay'], dtype=object)

# %%
df.occupation.value_counts()
df.occupation.unique()
# Out:
# array([' Machine-op-inspct', ' Farming-fishing', ' Protective-serv',
#        ' Other-service', ' Prof-specialty', ' Craft-repair',
#        ' Adm-clerical', ' Exec-managerial', ' Tech-support', ' Sales',
#        ' Priv-house-serv', ' Transport-moving', ' Handlers-cleaners',
#        ' Armed-Forces'], dtype=object)

# %%
df.sex.value_counts()
# Out:
#  Male      10147
#  Female     4913
# Name: sex, dtype: int64

# %% [markdown]
# # Finding Categorical and Numerical

# %%
#finding categorical and numerical
cat = [var for var in df.columns if df[var].dtype=='O']
print('There are {} categorical variables\n'.format(len(cat)))
print('The categorical variables are :\n\n', cat)
# Out:
# There are 9 categorical variables
#
# The categorical variables are :
#
#  ['workclass', 'education', 'maritalstatus', 'occupation', 'relationship', 'race', 'sex', 'native', 'Salary']

# %%
# finding numerical variables
num = [var for var in df.columns if df[var].dtype!='O']
print("There are {} numerical variables\n", format(len(num)))
print("The numerical variables are:", num)
# Out:
# There are {} numerical variables
#  5
# The numerical variables are: ['age', 'educationno', 'capitalgain', 'capitalloss', 'hoursperweek']

# %%
# check if there are any missing values in categorical variables

df[cat].isnull().sum()
# Out:
# age             0
# educationno     0
# capitalgain     0
# capitalloss     0
# hoursperweek    0
# dtype: int64

# %%
df[num].isnull().sum()
# Out:
# age             0
# educationno     0
# capitalgain     0
# capitalloss     0
# hoursperweek    0
# dtype: int64

# %% [markdown]
# # Visualization

# %%
sns.pairplot(df)

# %%
t1 = pd.crosstab(index=["education"],columns=["workclass"])
t1.plot(kind="bar")
plt.show()

# %%
t2 = pd.crosstab(index=["education"],columns=["Salary"])
t2.plot(kind="bar")
plt.show()

# %%
t3 = pd.crosstab(index=["sex"], columns=["race"])
t3.plot(kind="bar")
plt.show()

# %%
t4 = pd.crosstab(index=["maritalstatus"], columns=["sex"])
t4.plot(kind="bar")
plt.show()

# %%
df["age"].hist()
df["educationno"].hist()
df["capitalgain"].hist()
df["capitalloss"].hist()
df["hoursperweek"].hist()
plt.show()

# %%
# checking correlation among parameters
corr = df.corr()
fig, ax = plt.subplots(figsize=(8,8))

# %%
# Generating heatmap
sns.heatmap(corr, cmap="magma", annot=True, fmt=".2f")
plt.xticks(range(len(corr.columns)), corr.columns)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.show()

# %%
# Splitting the data into x and y
x = df.drop(["Salary"], axis=1)
y = df["Salary"]

# %%
# splitting x and y into training and testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33, random_state=0)

# %%
# display categorical variables
cat = [col for col in x_train.columns if x_train[col].dtype=='O']
cat
# Out:
# ['workclass',
#  'education',
#  'maritalstatus',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native']

# %%
# display numerical variables
num = [col for col in x_train.columns if x_train[col].dtype != 'O']
num
# Out:
# ['age', 'educationno', 'capitalgain', 'capitalloss', 'hoursperweek']

# %% [markdown]
# # Data Transformation

# %%
import category_encoders as ce
encoder = ce.OneHotEncoder(cols=["workclass","education","maritalstatus","occupation","relationship","race","sex","native"])

x_train = encoder.fit_transform(x_train)
x_test = encoder.fit_transform(x_test)
x_train.head()
# Out:
#        age  workclass_1  workclass_2  workclass_3  workclass_4  workclass_5  \
# 10313   34            1            0            0            0            0
# 1958    22            1            0            0            0            0
# 14855   59            0            1            0            0            0
# 8228    42            1            0            0            0            0
# 9416    44            1            0            0            0            0
#
#        workclass_6  workclass_7  education_1  education_2  ...  native_31  \
# 10313            0            0            1            0  ...          0
# 1958             0            0            0            1  ...          0
# 14855            0            0            0            0  ...          0
# 8228             0            0            0            0  ...          0
# 9416             0            0            0            0  ...          0
#
# ...

# %%
cols = x_train.columns

# %%
# importing StandrdScaler
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()

x_train = SS.fit_transform(x_train)
x_test = SS.fit_transform(x_test)

x_train = pd.DataFrame(x_train, columns=[cols])
x_test = pd.DataFrame(x_test, columns=[cols])
x_train.head()
# Out:
#         age workclass_1 workclass_2 workclass_3 workclass_4 workclass_5  \
# 0 -0.356575    0.603532   -0.197555   -0.178037   -0.212515   -0.305245
# 1 -1.252414    0.603532   -0.197555   -0.178037   -0.212515   -0.305245
# 2  1.509757   -1.656913    5.061886   -0.178037   -0.212515   -0.305245
# 3  0.240651    0.603532   -0.197555   -0.178037   -0.212515   -0.305245
# 4  0.389958    0.603532   -0.197555   -0.178037   -0.212515   -0.305245
#
#   workclass_6 workclass_7 education_1 education_2  ... native_31 native_32  \
# 0   -0.273662   -0.024393    1.924568   -0.705636  ... -0.028169 -0.041081
# 1   -0.273662   -0.024393   -0.519597    1.417162  ... -0.028169 -0.041081
# 2   -0.273662   -0.024393   -0.519597   -0.705636  ... -0.028169 -0.041081
# 3   -0.273662   -0.024393   -0.519597   -0.705636  ... -0.028169 -0.041081
# 4   -0.273662   -0.024393   -0.519597   -0.705636  ... -0.028169 -0.041081
#
#   native_33 native_34 native_35 native_36 native_37 native_38 native_39  \
# ...

# %%
# Model fitting
from sklearn.naive_bayes import GaussianNB
GNB = GaussianNB()

from sklearn.naive_bayes import GaussianNB
GNB = GaussianNB()
# fit the model
GNB.fit(x_train, y_train)

# prediction
y_pred_train = GNB.predict(x_train)
y_pred_test = GNB.predict(x_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(

# %%
# accuracay
from sklearn.metrics import accuracy_score
ac1 = accuracy_score(y_train,y_pred_train)
print("training score:", ac1.round(2))
ac2 = accuracy_score(y_test,y_pred_test)
print("test score:", ac2.round(2))
# Out:
# training score: 0.41
# test score: 0.75

# %%
# Bernoulli's
from sklearn.naive_bayes import BernoulliNB
BNB = BernoulliNB()
#fit the model
BNB.fit(x_train,y_train)
# prediction
y_pred_train = BNB.predict(x_train)
y_pred_test = BNB.predict(x_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(

# %%
# accuracy score
from sklearn.metrics import accuracy_score
ac1 = accuracy_score(y_train,y_pred_train)
print("training score:", ac1.round(2))
ac2 = accuracy_score(y_test,y_pred_test)
print("test score:", ac2.round(2))
# Out:
# training score: 0.78
# test score: 0.76

# %%
# SVC
from sklearn.svm import SVC
svc_class = SVC(kernel='linear')
#fit the model
svc_class.fit(x_train,y_train)
# prediction
y_pred_train = svc_class.predict(x_train)
y_pred_test = svc_class.predict(x_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(

# %%
# accuracy score
from sklearn.metrics import accuracy_score
ac1 = accuracy_score(y_train,y_pred_train)
print("training score:", ac1.round(2))
ac2 = accuracy_score(y_test,y_pred_test)
print("test score:", ac2.round(2))
# Out:
# training score: 0.85
# test score: 0.82

# %%
# LogisticRegression
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
# fit the model
logreg.fit(x_train,y_train)
# prediction
y_pred_train = logreg.predict(x_train)
y_pred_test = logreg.predict(x_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(

# %%
# accuracy score
ac1 = accuracy_score(y_train,y_pred_train)
print("training score:", ac1.round(2))
ac2 = accuracy_score(y_test,y_pred_test)
print("test score:", ac2.round(2))
# Out:
# training score: 0.85
# test score: 0.81

# %% [markdown]
# svc and logreg is best prediction models among the builted models
